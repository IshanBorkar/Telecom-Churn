# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db_host='18.136.56.185'
username='dm_team3'
password='dm_team15119#'
db_name='project_telecom'

# %%
connection=create_engine('mysql+pymysql://dm_team3:dm_team15119#@18.136.56.185/project_telecom')

# %%
connection.table_names()
# Out:
# ['telecom_churn_data']

# %%
query='select * from telecom_churn_data'
telecom_churn_data=pd.read_sql(query,connection)

# %%
print(telecom_churn_data.shape)
# Out:
# (4617, 21)

# %%
telecom_churn_data
# Out:
#      columns1 columns2 columns3   columns4 columns5 columns6 columns7  \
# 0          KS      128      415   382-4657       no      yes       25
# 1          OH      107      415   371-7191       no      yes       26
# 2          NJ      137      415   358-1921       no       no        0
# 3          OH       84      408   375-9999      yes       no        0
# 4          OK       75      415   330-6626      yes       no        0
# ...       ...      ...      ...        ...      ...      ...      ...
# 4612       NY       57      510   345-7512       no      yes       25
# 4613       NM      177      408   343-6820       no      yes       29
# 4614       VT       67      408   338-4794       no      yes       33
# 4615       MI       98      415   355-8388       no      yes       23
# 4616       IN      140      415   409-6884       no       no        0
#
#      columns8 columns9 columns10  ... columns12 columns13 columns14 columns15  \
# ...

# %%
telecom_churn_data.to_csv('telecom_churn_data.csv')

# %%
telecom_churn_data.to_excel('telecom_churn_data.xlsx')

# %%
telecom_churn_data.isna().sum().to_frame().T
# Out:
#    columns1  columns2  columns3  columns4  columns5  columns6  columns7  \
# 0         0         0         0         0         0         0         0
#
#    columns8  columns9  columns10  ...  columns12  columns13  columns14  \
# 0         0         0          0  ...          0          0          0
#
#    columns15  columns16  columns17  columns18  columns19  columns20  columns21
# 0          0          0          0          0          0          0          0
#
# [1 rows x 21 columns]

# %%
telecom_churn_data.isna().sum().T.any()
# Out:
# False
